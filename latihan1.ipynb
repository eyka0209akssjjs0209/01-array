# %% [markdown]
# <a href="https://colab.research.google.com/github/eyka0209akssjjs0209/tugas/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as bakso

# %%
dimensi1=bakso.array([20,10,30,40,50])

# %% [markdown]
# array satu dimensi

# %%
print(dimensi1)
# Out:
# [20 10 30 40 50]

# %% [markdown]
# menampilkan data dari index tertentu

# %%
wow=dimensi1[0]
print(wow)
# Out:
# 20

# %% [markdown]
# rata-rata, nilai terkecil, terbesar dari array tsb.

# %%
kecil=bakso.min(dimensi1)
besar=bakso.max(dimensi1)
rata2=bakso.mean(dimensi1)
print("nilai tercilik:", kecil)
print("nilai tERBESar:", besar)
print("nilai rata-rata:", rata2)
# Out:
# nilai tercilik: 10
# nilai tERBESar: 50
# nilai rata-rata: 30.0

# %% [markdown]
# arraY 2 dimensi

# %%
dimensi2= bakso.array([[1,3,5,6],
 [2,9,7,10]])

# %%
print(dimensi2)
hmmm= dimensi2[0,2]
print(hmmm)
# Out:
# [[ 1  3  5  6]
#  [ 2  9  7 10]]
# 5

# %% [markdown]
# array 3 dimensi

# %%
dimensi3= bakso.array([
    [[0,2,3],
     [4,5,6],
     [7,8,9]],
     [[10,12,13],
     [14,15,16],
     [17,18,19]]

])

# %%
ahoy=dimensi3[1,1,2]
print(ahoy)
# Out:
# 16
