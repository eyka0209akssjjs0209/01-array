# %% [markdown]
# <a href="https://colab.research.google.com/github/eyka0209akssjjs0209/01-array/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as bakso

# %%
jumlah=int(input("jumlah mahasiswa:"))
i=1
for i in range(1,jumlah):
    nm=input(f"nama mahasiswa ke- {i}:")
    ni=int(input(f"nilai mahasiswa ke- {i}:"))
i=+1
# Out:
# jumlah mahasiswa:3
# nama mahasiswa ke- 1:sadasd
# nilai mahasiswa ke- 1:22
# nama mahasiswa ke- 2:fsffv
# nilai mahasiswa ke- 2:33

# %%
kecil=min(ni)
print("nilai terkecil:", kecil)
besar=max(ni)
print("nilai terbesar:", besar)
rata2=sum(ni)/jumlah
print("nilai rata-rata:", rata2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_671/3836022343.py in <cell line: 0>()
# ----> 1 kecil=min(ni)
#       2 print("nilai terkecil:", kecil)
#       3 besar=max(ni)
#       4 print("nilai terbesar:", besar)
#       5 rata2=sum(ni)/jumlah
#
# TypeError: 'int' object is not iterable

# %%
# Out:
# 20

# %%
kecil=bakso.min(dimensi1)
besar=bakso.max(dimensi1)
rata2=bakso.mean(dimensi1)
print("nilai tercilik:", kecil)
print("nilai tERBESar:", besar)
print("nilai rata-rata:", rata2)
# Out:
# nilai tercilik: 10
# nilai tERBESar: 50
# nilai rata-rata: 30.0

# %%
dimensi2= bakso.array([[1,3,5,6],
 [2,9,7,10]])

# %%
print(dimensi2)
hmmm= dimensi2[0,2]
print(hmmm)
# Out:
# [[ 1  3  5  6]
#  [ 2  9  7 10]]
# 5

# %%
dimensi3= bakso.array([
    [[0,2,3],
     [4,5,6],
     [7,8,9]],
     [[10,12,13],
     [14,15,16],
     [17,18,19]]

])

# %%
ahoy=dimensi3[1,1,2]
print(ahoy)
# Out:
# 16
