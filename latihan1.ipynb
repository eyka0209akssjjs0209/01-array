# %% [markdown]
# <a href="https://colab.research.google.com/github/eyka0209akssjjs0209/01-array/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jumlah=int(input("jumlah mahasiswa:"))


nilay=[]
namay=[]
for i in range(1,jumlah+1):
    nm=input(f"nama mahasiswa ke- {i}:")
    namay.append(nm
                 )
    ni=int(input(f"nilai mahasiswa ke- {i}:"))
    nilay.append(ni)
i=+1
# Out:
# jumlah mahasiswa:10
# nama mahasiswa ke- 1:Reymoo
# nilai mahasiswa ke- 1:88
# nama mahasiswa ke- 2:Marisaay
# nilai mahasiswa ke- 2:87
# nama mahasiswa ke- 3:Keineee
# nilai mahasiswa ke- 3:100
# nama mahasiswa ke- 4:Mokoww
# nilai mahasiswa ke- 4:80
# nama mahasiswa ke- 5:Cirnu
# nilai mahasiswa ke- 5:30
# nama mahasiswa ke- 6:Ayayaya
# nilai mahasiswa ke- 6:59
# nama mahasiswa ke- 7:Sanayyy
# nilai mahasiswa ke- 7:90
# nama mahasiswa ke- 8:Koishhh
# nilai mahasiswa ke- 8:10
# nama mahasiswa ke- 9:Flankders
# nilai mahasiswa ke- 9:55
# nama mahasiswa ke- 10:Kaguayy
# nilai mahasiswa ke- 10:67

# %%
kecil=min(nilay)
print("nilai terkecil:", kecil)
besar=max(nilay)
print("nilai terbesar:", besar)
rata2=sum(nilay)/jumlah
print("nilai rata-rata:", rata2)
# Out:
# nilai terkecil: 10
# nilai terbesar: 100
# nilai rata-rata: 66.6

# %%
lulus=[score for score in nilay if score >=60] #tidak tahu caranya hitung jadi line satu ini 100% AI, saya tidak paham maksud code nya apa
print("mahasiswa lulus:",len(lulus))
# Out:
# mahasiswa lulus: 6

# %%
import numpy as bakso
grap=bakso.array([[nilay],[namay]])
print(grap)
# Out:
# [[['88' '87' '100' '80' '30' '59' '90' '10' '55' '67']]
#
#  [['Reymoo' 'Marisaay' 'Keineee' 'Mokoww' 'Cirnu' 'Ayayaya' 'Sanayyy'
#    'Koishhh' 'Flankders' 'Kaguayy']]]

# %%
import matplotlib.pyplot as hehe
hehe.bar(range(len(nilay)), nilay)
hehe.title("grafik nilai")
hehe.xlabel("nama")
hehe.ylabel("nilai")
hehe.xticks(range(len(namay)),namay) #katanya gemini biar nampilkan nama di bawah garis x begini code nya
hehe.show()

# %%
# mengikuti yang ada di latihan praktikum, kurang paham terutama di bagian .pie
import matplotlib.pyplot as oek_oek
labels = ['lulus', 'gak lulus']
sizes = (len(lulus), (jumlah-len(lulus)))
oek_oek.pie(sizes, labels=labels, autopct='%1.1f%%',
        startangle=90)
oek_oek.title("grafik lulus")
oek_oek.axis('equal')
oek_oek.show()
